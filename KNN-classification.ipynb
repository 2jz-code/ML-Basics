# %%
# !wget http://motioncore-umh.cs.umn.edu/4980/college.csv
# Out:
# --2023-11-15 19:19:27--  http://motioncore-umh.cs.umn.edu/4980/college.csv
# Resolving motioncore-umh.cs.umn.edu (motioncore-umh.cs.umn.edu)... 128.101.106.27
# Connecting to motioncore-umh.cs.umn.edu (motioncore-umh.cs.umn.edu)|128.101.106.27|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78854 (77K) [text/csv]
# Saving to: ‘college.csv.1’
#
# college.csv.1       100%[===================>]  77.01K  --.-KB/s    in 0.04s
#
# 2023-11-15 19:19:27 (2.07 MB/s) - ‘college.csv.1’ saved [78854/78854]

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
df = pd.read_csv("college.csv")

# %%
df
# Out:
#                              School Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
selective = [None] * 777
df['Selective'] = selective
df
# Out:
#                              School Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
for i in range(0, 777):
  if(df['Top10perc'][i] > 50):
    df['Selective'][i] = 'Yes'
  else:
    df['Selective'][i] = 'No'
df
# Out:
# <ipython-input-5-fbf8a233c154>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Selective'][i] = 'No'
# <ipython-input-5-fbf8a233c154>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Selective'][i] = 'Yes'
#                              School Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# ...

# %%
features = df[['S.F.Ratio', 'Expend', 'PhD', 'Grad.Rate', 'Selective']]
features
# Out:
#      S.F.Ratio  Expend  PhD  Grad.Rate Selective
# 0         18.1    7041   70         60        No
# 1         12.2   10527   29         56        No
# 2         12.9    8735   53         54        No
# 3          7.7   19016   92         59       Yes
# 4         11.9   10922   76         15        No
# ..         ...     ...  ...        ...       ...
# 772       21.0    4469   60         40        No
# 773       13.3    9189   73         83        No
# 774       14.4    8323   67         49        No
# 775        5.8   40386   96         99       Yes
# 776       18.1    4509   75         99        No
#
# [777 rows x 5 columns]

# %%
sns.pairplot(features)

# %%
sns.pairplot(features, hue='Selective')

# %%
names = list(features.columns)
names
# Out:
# ['S.F.Ratio', 'Expend', 'PhD', 'Grad.Rate', 'Selective']

# %%
X = df[['S.F.Ratio', 'perc.alumni', 'PhD', 'Grad.Rate']].to_numpy()
y = df[['Selective']].to_numpy()

# %%
y = y.tolist()
to_int = {'No' : 0, 'Yes' : 1}
y = [item for sublist in y for item in sublist]
y = [to_int[label] for label in y]

# %%
y = np.array(y)

# %%
X -= X.mean(axis=0) # subtract the mean for each feature
X /= X.std(axis=0) # divide each feature by its standard deviation

# %%
def train_test_split(X,y,test_size):
  numRows = y.size                     #number or rows in the entire dataset
  splitPoint = int((1-test_size)*numRows)  #the row index test_size% of the way through
  p = np.random.permutation(numRows)   #array for shuffling data
  X = X[p]
  y = y[p]

  #Training data array
  X_train = X[:splitPoint]  # training features
  y_train = y[:splitPoint]  # training labels

  #Testing data array
  X_test = X[splitPoint:]  # testing features
  y_test = y[splitPoint:] # testing labels

  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,0.33)

# %%
def nn_classify_sample(training_set, training_labels, new_example):
  dists = np.array([np.sum( (t-new_example)**2) for t in training_set])
  nearest = dists.argmin()
  return training_labels[nearest]

def nn_classify(train_data, train_features, test_features):
  num_result = test_features[:,0].size
  result = np.ones(num_result)
  for i in range(0,num_result):
    result[i] = nn_classify_sample(train_data, train_features, test_features[i])
  return result

# %%
def accuracy(classify, X_train, y_train, X_test, y_test):
  pred = classify(X_train, y_train, X_test)
  correct_pred = (pred == y_test)
  total_preds = y_test.size
  return correct_pred.sum()/total_preds

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (520, 4)
# (257, 4)
# (520,)
# (257,)

# %%
predictions = nn_classify(X_train, y_train, X_test)

# %%
accuracy(nn_classify, X_train, y_train, X_test, y_test)
# Out:
# 0.8988326848249028

# %%
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier

# %%
def knn_classifier(X_train, y_train, X_test):
  # instantiate learning model and fit data
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)

  # predict the response
  pred = knn.predict(X_test)
  return pred

# %%
y = np.ravel(y)

# %%
k = 2
X_train, X_test, y_train, y_test = train_test_split(X,y,0.33)
accuracy(knn_classifier, X_train, y_train, X_test, y_test)
# Out:
# 0.933852140077821

# %%
def avg_accuracy(knn_classifier, X, y, count = 200, split=0.33):
  acc = 0
  for _ in range(0,count):
    X_train, X_test, y_train, y_test = train_test_split(X,y,split)
    acc += accuracy(knn_classifier, X_train, y_train, X_test, y_test)
  return acc/count

# %%
k = 2
avg_accuracy(knn_classifier, X, y)
# Out:
# 0.916167315175096

# %%
import matplotlib.pyplot as plt

plt.scatter(X_test[:, 0], X_test[:, 1], c=knn_classifier(X_train, y_train, X_test), cmap='viridis')
plt.title('KNN Predictions')
plt.show()

# %%
ks = np.arange(1,91,3)
acc_list = []
for k_cur in ks:
  k = k_cur
  acc = avg_accuracy(knn_classifier, X, y)
  acc_list.append(acc)
acc_list
# Out:
# [0.8901167315175088,
#  0.9207587548638123,
#  0.9279961089494152,
#  0.924455252918287,
#  0.9265564202334617,
#  0.9248054474708159,
#  0.9268871595330727,
#  0.9250583657587541,
#  0.9284824902723724,
#  0.9227431906614774,
#  0.9234435797665355,
#  0.9194163424124504,
#  0.9168287937743184,
#  0.9136770428015554,
#  0.9124708171206217,
#  0.9115564202334615,
#  0.9123540856031117,
#  0.9097859922178982,
#  0.9076848249027226,
#  0.9060116731517499,
#  0.9051556420233453,
#  0.9029961089494158,
#  0.9032879377431895,
#  0.9019649805447457,
#  0.9020622568093376,
#  0.9005447470817106,
#  0.9015175097276255,
#  0.8993385214007774,
#  0.8989883268482486,
#  0.8999027237354071]

# %%
sns.lineplot(x=ks,y=acc_list)
# Out:
# <Axes: >

# %%
ks_df = pd.DataFrame(ks, columns = ["k"])
acc_df = pd.DataFrame(acc_list, columns = ["Accuracy"])
sns.lineplot(x=ks_df.k,y=acc_df.Accuracy)
# Out:
# <Axes: xlabel='k', ylabel='Accuracy'>

# %%
fig = sns.lineplot(x=ks,y=acc_list)
plt.xlabel("k")
plt.ylabel("Avg Accuracy")
plt.title("Accuracy for various k-values in KNN")
plt.show(fig)

# %%
knn_train_pred = knn_classifier(X_train, y_train, X_train)
knn_test_pred = knn_classifier(X_train, y_train, X_test)

# %%
ones_test = np.ones(len(y_test))
ones_train = np.ones(len(y_train))
zeros_test = np.zeros(len(y_test))
zeros_train = np.zeros(len(y_train))

# %%
# low k classifier
low_k = KNeighborsClassifier(n_neighbors=5)
low_k.fit(X_train, y_train)

low_k_pred_train = low_k.predict(X_train)
low_k_pred_test = low_k.predict(X_test)

# %%
# high k classifier
high_k = KNeighborsClassifier(n_neighbors = 100)
high_k.fit(X_train, y_train)

high_k_pred_train = high_k.predict(X_train)
high_k_pred_test = high_k.predict(X_test)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
# knn train metrics
precision = precision_score(y_train, knn_train_pred)
recall = recall_score(y_train, knn_train_pred)
f1 = f1_score(y_train, knn_train_pred)
accuracy = accuracy_score(y_train, knn_train_pred)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)
# Out:
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Accuracy: 0.8769230769230769
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# knn test metrics
precision = precision_score(y_test, knn_test_pred)
recall = recall_score(y_test, knn_test_pred)
f1 = f1_score(y_test, knn_test_pred)
accuracy = accuracy_score(y_test, knn_test_pred)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)
# Out:
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Accuracy: 0.9455252918287937
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#low k train metrics
precision = precision_score(y_train, low_k_pred_train)
recall = recall_score(y_train, low_k_pred_train)
f1 = f1_score(y_train, low_k_pred_train)
accuracy = accuracy_score(y_train, low_k_pred_train)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)
# Out:
# Precision: 0.8717948717948718
# Recall: 0.53125
# F1 Score: 0.6601941747572816
# Accuracy: 0.9326923076923077

# %%
#low k test metrics
precision = precision_score(y_test, low_k_pred_test)
recall = recall_score(y_test, low_k_pred_test)
f1 = f1_score(y_test, low_k_pred_test)
accuracy = accuracy_score(y_test, low_k_pred_test)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)
# Out:
# Precision: 0.5
# Recall: 0.2857142857142857
# F1 Score: 0.36363636363636365
# Accuracy: 0.9455252918287937

# %%
# high k train metrics
precision = precision_score(y_train, high_k_pred_train, zero_division=0)
recall = recall_score(y_train, high_k_pred_train)
f1 = f1_score(y_train, high_k_pred_train)
accuracy = accuracy_score(y_train, high_k_pred_train)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)
# Out:
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Accuracy: 0.8769230769230769

# %%
# high k test metrics
precision = precision_score(y_test, high_k_pred_test, zero_division=0)
recall = recall_score(y_test, high_k_pred_test)
f1 = f1_score(y_test, high_k_pred_test)
accuracy = accuracy_score(y_test, high_k_pred_test)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)
# Out:
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Accuracy: 0.9455252918287937

# %%
# ones train metrics
precision = precision_score(y_train, ones_train)
recall = recall_score(y_train, ones_train)
f1 = f1_score(y_train, ones_train)
accuracy = accuracy_score(y_train, ones_train)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)

# %%
# ones test metrics
precision = precision_score(y_test, ones_test)
recall = recall_score(y_test, ones_test)
f1 = f1_score(y_test, ones_test)
accuracy = accuracy_score(y_test, ones_test)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)

# %%
# zeros train metrics
precision = precision_score(y_train, zeros_train, zero_division=0)
recall = recall_score(y_train, zeros_train)
f1 = f1_score(y_train, zeros_train)
accuracy = accuracy_score(y_train, zeros_train)


print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)

# %%
# ones test metrics
precision = precision_score(y_test, zeros_test, zero_division=0)
recall = recall_score(y_test, zeros_test)
f1 = f1_score(y_test, zeros_test)
accuracy = accuracy_score(y_test, zeros_test)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)

# %%
new_college = {
    'Apps': [5000],
    'Accept': [2600],
    'Enroll': [1000],
    'Top10perc': [0],
    'Top25perc': [0],
    'F.Undergrad' : [4300],
    'P.Undergrad' : [500],
    'Outstate': [14000],
    'Room.Board': [5000],
    'Books': [600],
    'Personal': [1200],
    'PhD': [84],
    'Terminal': [90],
    'S.F.Ratio': [12.1],
    'perc.alumni': [30],
    'Expend': [15700],
    'Grad.Rate': [78]
}

new_df = pd.DataFrame(new_college)
new_x = new_df[['S.F.Ratio', 'Expend', 'PhD', 'Grad.Rate']]
new_x = new_x.to_numpy()

# %%
knn_classifier(X_train, y_train, new_x)
